# %% [markdown]
# ## 学习尝试用theano搭建多层GRU网络

# %%
import os
import re
import random
import itertools
import nltk
import operator
import numpy as np
import theano
import theano.tensor as T
from numpy.random import uniform as uniform
from numpy import sqrt as sqrt
import pickle

# %%
corpus_name = "cornell movie-dialogs corpus"
corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='utf8') as f:
        for line in f:
            #if (line % 100 == 0):
            #print(line)
            values = line.split(" +++$+++ ")
           # print(values)
            # Extract fields
            lineObj = {}
            #print(fields)
            for i, field in enumerate(fields):
                #if (i % 100 == 0):
                #print(i,field,values[i])
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines


# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='utf8') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            #print(values)
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token
#trimmed  是否修剪
class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD
#
    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold过滤低频词
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)
MAX_LENGTH = 15  # Maximum sentence length to consider需要考虑的最大句子长度
datafile = os.path.join( "data/训练数据.txt")


# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    #lower()到小写
    #Python strip() 方法用于移除字符串头尾指定的字符（默认为空格或换行符）或字符序列。
    s = s.lower().strip()
    #与大多数编程语言相同，知正则表达式里使用"\"作为转义字符，这就可能造成反斜杠困扰。假如你需要匹配文本中的字符"\"，
    #那么使用编程道语言表示的正则表达式版里将需要4个反斜杠"\\\\"：前两个和后两个分别用于在编程语言里转义成反斜杠，
    #转换成两个反斜杠后再在正则表达式里转义成一个反斜杠。Python里的原生字符串很好地解决了这个问题，
    #这个例子中的正则表达式可以使用r"\\"表示。同样，匹配一个数字的"\\d"可以写成r"\d"。有了原生字符串，
    #你再也不用担心是不是漏写了反斜杠，写出来的表达式也更直观。
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[,']+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object读取查询/响应对并返回voc对象
def readVocs(datafile, corpus_name):
    print("Reading lines..."+corpus_name)
    print("datafile..."+datafile)
    # Read the file and split into lines

    lines = open(datafile, encoding='utf-8').\
    read().strip().split('\n')#这里反斜杆是续行符
    # Split every line into pairs and normalize 将每一行分成几对并归一化
    pairs = [[normalizeString(s) for s in l.split('【*分割*】')] for l in lines]
    #实例化类Voc
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
#如果对“ p”中的两个句子都在MAX_LENGTH阈值以下，则返回True
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token输入序列需要保留EOS令牌的最后一个字
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition使用filterPair条件的过滤器对
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
# 使用上面定义的函数，返回填充的voc对象和配对列表
def loadPrepareData(corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)#这里读取会话对
    print("Read {!s} sentence pairs".format(len(pairs)))#格式化字符串操作
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs加载/组装voc和对
save_dir = os.path.join("data", "save")
print("save_dir",save_dir)
#os.path.join 运行路径中加入新的文件夹

voc, pairs = loadPrepareData(corpus_name, datafile, save_dir)
# Print some pairs to validate打印一些对以进行验证
print("\npairs:")
for pair in pairs[:2]:
    print(pair)#pairs数组 成员是字符串数组
# Out:
# save_dir data\save
# Start preparing training data ...
# Reading lines...cornell movie-dialogs corpus
# datafile...data/训练数据.txt
# Read 529586 sentence pairs
# Trimmed to 114074 sentence pairs
# Counting words...
# Counted words: 86302
#
# pairs:
# ['这场 也 有 免费 的 直播 ？ 达胜', '达胜 24 直播 网有 免费 高清 的']
# ['这种 饼 也 只有 奉先能 吃 不然 又 闷平 交出 签名 车牌号', '交出 签名 车牌号 juc - 635']

# %%
MIN_COUNT = 10    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc语音中MIN_COUNT下使用的修饰词
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words过滤掉带有修饰词的词对
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence检查输入句子
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
SENTENCE_START_TOKEN = "SENTENCE_START"
SENTENCE_END_TOKEN = "SENTENCE_END"
UNKNOWN_TOKEN = "UNKNOWN_TOKEN"
b=nltk.word_tokenize(pairs[0][0])

会话对_分割1= [nltk.word_tokenize('SENTENCE_START '+pair[0]+' SENTENCE_END')+nltk.word_tokenize('SENTENCE_START '+pair[1]+' SENTENCE_END') for pair in pairs]
会话对_分割= [ [nltk.word_tokenize('SENTENCE_START '+对+' SENTENCE_END')for 对 in pair]for pair in pairs]
词频 = nltk.FreqDist(itertools.chain(*会话对_分割1))
词汇数量=len(词频.items())

词汇_降序 = sorted(词频.items(), key=lambda x: (x[1], x[0]), reverse=True)[:词汇数量-2]
词汇_升序 = sorted(词汇_降序, key=operator.itemgetter(1))
下标_到_单词 = ["<MASK/>", UNKNOWN_TOKEN] + [x[0] for x in 词汇_升序]
单词_到_下标 = dict([(w, i) for i, w in enumerate(下标_到_单词)])
for i, 分割 in enumerate(会话对_分割):
    会话对_分割[i] =[[w if w in 单词_到_下标 else UNKNOWN_TOKEN for w in 部]for 部 in 分割]
X_train = np.asarray([[单词_到_下标[w] for w in 分割[0][:-1]] for 分割 in 会话对_分割])
y_train = np.asarray([[单词_到_下标[w] for w in 分割[1][1:]] for 分割 in 会话对_分割])
# Out:
# keep_words 13451 / 86299 = 0.1559
# Trimmed from 114074 pairs to 40345, 0.3537 of total

# %%
def 打包训练数据(输入,输出,包数=10,包大小=10):
    包_输入_集=[]
    输入_遮罩_集=[]
    for 数1 in range(包数):
        包_输入=[]
        P=[i for i in range(数1*包大小,数1*包大小+(包大小))]

        NP=输入[P]
        记录长度=0
        for j in NP:
            if len(j)>记录长度:
                记录长度=len(j)
        计数=0
        for j in NP:
            补齐数=记录长度-len(j)
            输入_遮罩_临=np.ones(len(j))
            for k in range(补齐数):
                j.append(0)
                输入_遮罩_临=np.append(输入_遮罩_临,0.)
            #包_输入.append(j)
        #print(len(包_输入))
            if 计数==0:
                包_输入=np.array(j).reshape(记录长度,1)
                输入_遮罩=输入_遮罩_临.reshape(记录长度,1)
            else:
                输入_遮罩=np.concatenate((输入_遮罩,输入_遮罩_临.reshape(记录长度,1)),axis=1)
                包_输入=np.concatenate((包_输入,np.array(j).reshape(记录长度,1)),axis=1)
            计数+=1
        包_输入_集.append(包_输入) 
        输入_遮罩_集.append(输入_遮罩)
        
    输出_遮罩_集=[]
    包_输出_集=[]
    for 数1 in range(包数):
        包_输出=[]
        P=[i for i in range(数1*包大小,数1*包大小+(包大小))]

        NP=输出[P]
        记录长度=0
        for j in NP:
            if len(j)>记录长度:
                记录长度=len(j)
        计数=0
        for j in NP:
            补齐数=记录长度-len(j)
            输出_遮罩_临=np.ones(len(j))
            for k in range(补齐数):
                j.append(0)
                输出_遮罩_临=np.append(输出_遮罩_临,0.)
            if 计数==0:
                包_输出=np.array(j).reshape(记录长度,1)
                输出_遮罩=输出_遮罩_临.reshape(记录长度,1)
            else:
                
                输出_遮罩=np.concatenate((输出_遮罩,输出_遮罩_临.reshape(记录长度,1)),axis=1)
                包_输出=np.concatenate((包_输出,np.array(j).reshape(记录长度,1)),axis=1)
            计数+=1
        包_输出_集.append(包_输出)
        输出_遮罩_集.append(输出_遮罩)
    return 包_输入_集 , 包_输出_集 ,输入_遮罩_集,输出_遮罩_集

包_输入 , 包_输出,输入_遮罩_集,输出_遮罩_集=打包训练数据(X_train,y_train,200,200)

# %%
class 预处理_正交():
	def __init__(self, 词向量尺寸=100, 隐藏层尺寸=300):
		self.隐藏层尺寸 = 隐藏层尺寸

		E = uniform(-sqrt(1. / 词向量尺寸), sqrt(1. / 词向量尺寸), (隐藏层尺寸, 词向量尺寸))
		self.E = theano.shared(name='E', value=E.astype(theano.config.floatX))
		self.mE = theano.shared(name='mE', value=np.zeros(E.shape).astype(theano.config.floatX))
		self.参数 = [self.E]
		self.rms = [self.mE]
	def 前向传播(self,输入):

		def 前向_单步(输入_E,E_1):
			输出_E = E_1[:,输入_E]
			return 输出_E

		单层输出, updates = theano.scan(
			fn = 前向_单步,
			sequences = [ 输入],
			non_sequences = [self.E]
			)
		return 单层输出

# %%
class GRU_单位_集束():
	def __init__(self,  隐藏层尺寸=300, 求导深度=-1):
		self.隐藏层尺寸 = 隐藏层尺寸
		self.求导深度 = 求导深度

		U = np.random.uniform(-np.sqrt(1. / 隐藏层尺寸), np.sqrt(1. / 隐藏层尺寸), (3 * 隐藏层尺寸, 隐藏层尺寸))
		W = np.random.uniform(-np.sqrt(1. / 隐藏层尺寸), np.sqrt(1. / 隐藏层尺寸), (3 * 隐藏层尺寸, 隐藏层尺寸))

		self.U = theano.shared(name='U', value=U.astype(theano.config.floatX))
		self.W = theano.shared(name='W', value=W.astype(theano.config.floatX))
		self.mU = theano.shared(name='mU', value=np.zeros(U.shape).astype(theano.config.floatX))
		self.mW = theano.shared(name='mW', value=np.zeros(W.shape).astype(theano.config.floatX))
		self.参数 = [self.W, self.U]
		self.rms= [self.mW, self.mU]
	def 前向传播(self,输入,遮罩,集束量,隐层_单步_0=None):
		if 隐层_单步_0 == None:
			隐层_单步_0=T.zeros((self.隐藏层尺寸,集束量))
#			隐层_单步_0 = T.alloc(np.asarray(0., dtype=theano.config.floatX), self.隐藏层尺寸, 集束量)
		def 前向_单步( 输入_E, 遮罩,隐层_单步_前,W,U,隐藏层尺寸):
			更新门 = T.nnet.hard_sigmoid(U[0:隐藏层尺寸, :].dot(输入_E) + W[0:隐藏层尺寸, :].dot(隐层_单步_前))
			重置门 = T.nnet.hard_sigmoid(
				U[1 * 隐藏层尺寸:2 * 隐藏层尺寸, :].dot(输入_E) + W[1 * 隐藏层尺寸:2 * 隐藏层尺寸, :].dot(
					隐层_单步_前))
			记忆单元 = T.tanh(
				U[2 * 隐藏层尺寸:3 * 隐藏层尺寸, :].dot(输入_E) + W[2 * 隐藏层尺寸:3 * 隐藏层尺寸, :].dot(
					隐层_单步_前 * 重置门))
			隐层_单步 = (T.ones_like(更新门) - 更新门) * 记忆单元 + 更新门 * 隐层_单步_前
			隐层_单步 = 遮罩[None,:]*隐层_单步 + (1.0 - 遮罩)[None,:]*隐层_单步_前            
			return 隐层_单步
		单层输出, updates = theano.scan(
			fn = 前向_单步,
			truncate_gradient=self.求导深度,
			sequences = [ 输入,遮罩],
			outputs_info = [隐层_单步_0],
			non_sequences = [self.W, self.U,self.隐藏层尺寸]
			)
		return 单层输出

# %%
class GRU_注意力():
	def __init__(self,  隐藏层尺寸=300, 注意力尺寸=300,求导深度=-1):
		self.隐藏层尺寸 = 隐藏层尺寸
		self.求导深度 = 求导深度

		W = np.random.uniform(-np.sqrt(1. / np.sqrt(注意力尺寸*隐藏层尺寸)), np.sqrt(1. / np.sqrt(注意力尺寸*隐藏层尺寸)), (注意力尺寸, 隐藏层尺寸))
		V = np.random.uniform(-np.sqrt(1. / np.sqrt(注意力尺寸)), np.sqrt(1. / np.sqrt(注意力尺寸)), (注意力尺寸))

		self.W = theano.shared(name='W', value=W.astype(theano.config.floatX))
		self.V = theano.shared(name='V', value=V.astype(theano.config.floatX))
		self.mW = theano.shared(name='mW', value=np.zeros(W.shape).astype(theano.config.floatX))
		self.mV = theano.shared(name='mV', value=np.zeros(V.shape).astype(theano.config.floatX))
		self.参数 = [self.W, self.V]
		self.rms= [self.mW, self.mV]
	def 前向传播(self,输入):
		def 前向_单步_1( 输入_E,W,V):

			E = V.dot(T.tanh(W.dot(输入_E)))

			return E
		E, updates = theano.scan(
			fn = 前向_单步_1,
			truncate_gradient=self.求导深度,
			sequences = [ 输入],
			non_sequences = [self.W, self.V]
			)
		E_sum=T.sum(E,axis=0)
		def 前向_单步_2( E,E_sum):
           
			注意力_分=E/E_sum

			return 注意力_分
		注意力分配, updates = theano.scan(
			fn = 前向_单步_2,
			truncate_gradient=self.求导深度,
			sequences = [ E],
			non_sequences = [E_sum]
			)
		def 前向_单步_3( 输入_E,注意力_分):
			AH_分=注意力_分*输入_E 
             
			return AH_分                      
		AH_分_集, updates = theano.scan(
			fn = 前向_单步_3,
			truncate_gradient=self.求导深度,
			sequences = [输入, 注意力分配]
			)
#		AH_分_集 = theano.printing.Print('this is AH_分_集 value')(AH_分_集)
		隐层_新=T.sum(AH_分_集,axis=0)
		return 隐层_新

# %%
class GRU_单位_集束_A():
	def __init__(self,  隐藏层尺寸=300, 求导深度=-1):
		self.隐藏层尺寸 = 隐藏层尺寸
		self.求导深度 = 求导深度

		U = np.random.uniform(-np.sqrt(1. / 隐藏层尺寸), np.sqrt(1. / 隐藏层尺寸), (3 * 隐藏层尺寸, 隐藏层尺寸))
		W = np.random.uniform(-np.sqrt(1. / 隐藏层尺寸), np.sqrt(1. / 隐藏层尺寸), (3 * 隐藏层尺寸, 隐藏层尺寸))

		self.U = theano.shared(name='U', value=U.astype(theano.config.floatX))
		self.W = theano.shared(name='W', value=W.astype(theano.config.floatX))
		self.mU = theano.shared(name='mU', value=np.zeros(U.shape).astype(theano.config.floatX))
		self.mW = theano.shared(name='mW', value=np.zeros(W.shape).astype(theano.config.floatX))
		self.参数 = [self.W, self.U]
		self.rms= [self.mW, self.mU]
	def 前向传播(self,输入,遮罩,集束量,隐层_单步_0=None):
		if 隐层_单步_0 == None:
			隐层_单步_0=T.zeros((self.隐藏层尺寸,集束量))
#			隐层_单步_0 = T.alloc(np.asarray(0., dtype=theano.config.floatX), self.隐藏层尺寸, 集束量)
		def 前向_单步( 输入_E, 遮罩,隐层_单步_前,W,U,隐藏层尺寸):
			更新门 = T.nnet.hard_sigmoid(U[0:隐藏层尺寸, :].dot(输入_E) + W[0:隐藏层尺寸, :].dot(隐层_单步_前))
			重置门 = T.nnet.hard_sigmoid(
				U[1 * 隐藏层尺寸:2 * 隐藏层尺寸, :].dot(输入_E) + W[1 * 隐藏层尺寸:2 * 隐藏层尺寸, :].dot(
					隐层_单步_前))
			记忆单元 = T.tanh(
				U[2 * 隐藏层尺寸:3 * 隐藏层尺寸, :].dot(输入_E) + W[2 * 隐藏层尺寸:3 * 隐藏层尺寸, :].dot(
					隐层_单步_前 * 重置门))
			隐层_单步 = (T.ones_like(更新门) - 更新门) * 记忆单元 + 更新门 * 隐层_单步_前
#			隐层_单步 = 遮罩[None,:]*隐层_单步 + (1.0 - 遮罩)[None,:]*隐层_单步_前            
			return 隐层_单步
		单层输出, updates = theano.scan(
			fn = 前向_单步,
			truncate_gradient=self.求导深度,
			sequences = [ 输入,遮罩],
			outputs_info = [隐层_单步_0],
			non_sequences = [self.W, self.U,self.隐藏层尺寸]
			)
		return 单层输出

# %%
class GRU_单位2_集束():
	def __init__(self,  隐藏层尺寸=300, 求导深度=-1):
		self.隐藏层尺寸 = 隐藏层尺寸
		self.求导深度 = 求导深度

		U = np.random.uniform(-np.sqrt(1. / 隐藏层尺寸), np.sqrt(1. / 隐藏层尺寸), (3 * 隐藏层尺寸, 隐藏层尺寸))
		W = np.random.uniform(-np.sqrt(1. / 隐藏层尺寸), np.sqrt(1. / 隐藏层尺寸), (3 * 隐藏层尺寸, 隐藏层尺寸))

		self.U = theano.shared(name='U', value=U.astype(theano.config.floatX))
		self.W = theano.shared(name='W', value=W.astype(theano.config.floatX))
		self.mU = theano.shared(name='mU', value=np.zeros(U.shape).astype(theano.config.floatX))
		self.mW = theano.shared(name='mW', value=np.zeros(W.shape).astype(theano.config.floatX))
		self.参数 = [self.W, self.U]
		self.rms= [self.mW, self.mU]
	def 前向传播(self,遮罩,集束量,隐层_单步_0=None):
		if 隐层_单步_0 == None:
			隐层_单步_0=T.zeros((self.隐藏层尺寸,集束量))
#			隐层_单步_0 = T.alloc(np.asarray(0., dtype=theano.config.floatX), self.隐藏层尺寸, 集束量)
		def 前向_单步( 遮罩,隐层_单步_前,W,U,隐藏层尺寸):
			更新门 = T.nnet.hard_sigmoid(U[0:隐藏层尺寸, :].dot(隐层_单步_前) + W[0:隐藏层尺寸, :].dot(隐层_单步_前))
			重置门 = T.nnet.hard_sigmoid(
				U[1 * 隐藏层尺寸:2 * 隐藏层尺寸, :].dot(隐层_单步_前) + W[1 * 隐藏层尺寸:2 * 隐藏层尺寸, :].dot(
					隐层_单步_前))
			记忆单元 = T.tanh(
				U[2 * 隐藏层尺寸:3 * 隐藏层尺寸, :].dot(隐层_单步_前) + W[2 * 隐藏层尺寸:3 * 隐藏层尺寸, :].dot(
					隐层_单步_前 * 重置门))
			隐层_单步 = (T.ones_like(更新门) - 更新门) * 记忆单元 + 更新门 * 隐层_单步_前
			隐层_单步 = 遮罩[None,:]*隐层_单步 + (1.0 - 遮罩)[None,:]*隐层_单步_前 
			return 隐层_单步
		单层输出, updates = theano.scan(
			fn = 前向_单步,
			sequences = [ 遮罩],
			truncate_gradient=self.求导深度,
			outputs_info = [隐层_单步_0],
			non_sequences = [self.W, self.U,self.隐藏层尺寸])
		return 单层输出

# %%
class GRU_单位2_集束_A():
	def __init__(self,  隐藏层尺寸=300, 求导深度=-1):
		self.隐藏层尺寸 = 隐藏层尺寸
		self.求导深度 = 求导深度

		U = np.random.uniform(-np.sqrt(1. / 隐藏层尺寸), np.sqrt(1. / 隐藏层尺寸), (3 * 隐藏层尺寸, 隐藏层尺寸))
		W = np.random.uniform(-np.sqrt(1. / 隐藏层尺寸), np.sqrt(1. / 隐藏层尺寸), (3 * 隐藏层尺寸, 隐藏层尺寸))

		self.U = theano.shared(name='U', value=U.astype(theano.config.floatX))
		self.W = theano.shared(name='W', value=W.astype(theano.config.floatX))
		self.mU = theano.shared(name='mU', value=np.zeros(U.shape).astype(theano.config.floatX))
		self.mW = theano.shared(name='mW', value=np.zeros(W.shape).astype(theano.config.floatX))
		self.参数 = [self.W, self.U]
		self.rms= [self.mW, self.mU]
	def 前向传播(self,遮罩,集束量,隐层_单步_0=None):
		if 隐层_单步_0 == None:
			隐层_单步_0=T.zeros((self.隐藏层尺寸,集束量))
#			隐层_单步_0 = T.alloc(np.asarray(0., dtype=theano.config.floatX), self.隐藏层尺寸, 集束量)
		def 前向_单步( 遮罩,隐层_单步_前,W,U,隐藏层尺寸):
			更新门 = T.nnet.hard_sigmoid(U[0:隐藏层尺寸, :].dot(隐层_单步_前) + W[0:隐藏层尺寸, :].dot(隐层_单步_前))
			重置门 = T.nnet.hard_sigmoid(
				U[1 * 隐藏层尺寸:2 * 隐藏层尺寸, :].dot(隐层_单步_前) + W[1 * 隐藏层尺寸:2 * 隐藏层尺寸, :].dot(
					隐层_单步_前))
			记忆单元 = T.tanh(
				U[2 * 隐藏层尺寸:3 * 隐藏层尺寸, :].dot(隐层_单步_前) + W[2 * 隐藏层尺寸:3 * 隐藏层尺寸, :].dot(
					隐层_单步_前 * 重置门))
			隐层_单步 = (T.ones_like(更新门) - 更新门) * 记忆单元 + 更新门 * 隐层_单步_前
#			隐层_单步 = 遮罩[None,:]*隐层_单步 + (1.0 - 遮罩)[None,:]*隐层_单步_前 
			return 隐层_单步
		单层输出, updates = theano.scan(
			fn = 前向_单步,
			sequences = [ 遮罩],
			truncate_gradient=self.求导深度,
			outputs_info = [隐层_单步_0],
			non_sequences = [self.W, self.U,self.隐藏层尺寸])
		return 单层输出

# %%
class 后处理_输出():
	def __init__(self, 词向量尺寸=100, 隐藏层尺寸=300):
		self.隐藏层尺寸 = 隐藏层尺寸

		V = uniform(-sqrt(1./隐藏层尺寸), sqrt(1./隐藏层尺寸), (词向量尺寸, 隐藏层尺寸))
		self.V = theano.shared(name='V', value=V.astype(theano.config.floatX))
		self.mV = theano.shared(name='mV', value=np.zeros(V.shape).astype(theano.config.floatX))
		self.参数 = [self.V]
		self.rms = [self.mV]
	def 前向传播(self,输入):

		def 前向_单步(输入_V,V_1):
			输出_V = V_1.dot(输入_V)
			return 输出_V

		单层输出, updates = theano.scan(
			fn = 前向_单步,
			sequences = [ 输入],
			non_sequences = [self.V]
			)
		return 单层输出

# %%
class GRU_集束():
	def __init__(self, 词向量尺寸=100, 隐藏层尺寸=300,层数=2,求导深度=-1):
		self.层数=层数
		self.词向量尺寸=词向量尺寸
		self.隐藏层尺寸=隐藏层尺寸
		self.求导深度=求导深度
		self.参数=[]
		self.rms=[]
		输入 = T.imatrix('i')
		目标输出  = T.imatrix('o')
		输入_遮罩= T.fmatrix('mi')
		输出_遮罩= T.fmatrix('m0')        
		目标长度 = T.iscalar("k") 
		集束量= T.iscalar("b") 
        
		预处理=预处理_正交(self.词向量尺寸,self.隐藏层尺寸)
		self.参数+=预处理.参数
		self.rms+=预处理.rms
		输出_内=预处理.前向传播(输入)
        
        
		for i in range(self.层数):
			GRU层=GRU_单位_集束(self.隐藏层尺寸)
			self.参数+=GRU层.参数
			self.rms+=GRU层.rms
			输出_内=GRU层.前向传播(输出_内,输入_遮罩,集束量)
#		信息包=输出_内[-1]

		注意力层=GRU_注意力(self.隐藏层尺寸,self.隐藏层尺寸)
		self.参数+=注意力层.参数
		self.rms+=注意力层.rms            
		信息包=注意力层.前向传播(输出_内)            
        
		GRU层2=GRU_单位2_集束_A(self.隐藏层尺寸)
		self.参数+=GRU层2.参数
		self.rms+=GRU层2.rms
		输出_内2=GRU层2.前向传播(输出_遮罩,集束量,信息包)
#		信息包 = theano.printing.Print('this is 信息包 value')(信息包)        
		for i in range(self.层数-1):
			GRU层=GRU_单位_集束_A(self.隐藏层尺寸)
			self.参数+=GRU层.参数
			self.rms+=GRU层.rms
			输出_内2=GRU层.前向传播(输出_内2,输出_遮罩,集束量) 
            
            
		输出层=后处理_输出(self.词向量尺寸,self.隐藏层尺寸)
		self.参数+=输出层.参数
		self.rms+=输出层.rms
		输出_内2=输出层.前向传播(输出_内2)

		softmax_输出, updates = theano.scan(
			fn=lambda x: T.nnet.softmax(x.T),
			sequences=[输出_内2],
			)
# 		softmax_输出 = theano.printing.Print('this is softmax_输出 value')(softmax_输出)
		误差, updates = theano.scan(
			fn=lambda x,O:T.sum(T.nnet.categorical_crossentropy(x, O)),
			sequences=[softmax_输出,目标输出],
			)    
		误差 = T.sum(误差)




		参数集_导 = [T.grad(误差, 参数) for 参数 in self.参数]
		衰减系数 = T.scalar('L')
		学习率_变 = T.scalar('d')
		rms集= [衰减系数 * rms+ (1 - 衰减系数) * 参数_导 ** 2 for rms, 参数_导 in zip(self.rms, 参数集_导)]        
		参数_更新 = [(参数, 参数 - 学习率_变 * 参数_导/ T.sqrt(rms_更新 + 1e-6)) for 参数, 参数_导,rms_更新 in zip(self.参数, 参数集_导,rms集)]
		rms集_更新=[(rms, rms_更新) for rms,rms_更新 in zip(self.rms,rms集)]
		参数_更新+=rms集_更新               
        
		self.输出_预测 = theano.function(
					inputs=[输入,输入_遮罩,输出_遮罩,集束量],
					outputs=[softmax_输出],
					allow_input_downcast=True,
					on_unused_input='ignore'
					)
        
		self.训练 = theano.function(
			inputs=[输入,输入_遮罩,目标输出,输出_遮罩,集束量,theano.Param(学习率_变, default=0.1), theano.Param(衰减系数, default=0.9)],
			outputs=[误差],
			updates=参数_更新,
			allow_input_downcast=True,
					on_unused_input='ignore'
			)          
        
        
	def 预测(self, 输入,输入_遮罩,输出_遮罩,集束量):
		 return self.输出_预测(输入,输入_遮罩,输出_遮罩,集束量)
	def 训练(self, 输入,输入_遮罩,目标输出,输出_遮罩,集束量,学习率,衰减率):
		 return self.训练(输入,输入_遮罩,目标输出,输出_遮罩,集束量,学习率,衰减率)

# %%
np.random.seed(1)
import time
词汇总数 =13451
学习率 = 1e-3
隐藏层尺寸 = 512
层数=2

# print(包_输入[0].shape[1])
# #输出=模型2.预测误差(包_输入[0],包_输出[0],len(包_输出[0]),包_输入[0].shape[1])
# 输出=模型2.训练(包_输入[0],包_输出[0],len(包_输出[0]),包_输入[0].shape[1],学习率,0.9)
# print(输出[-1])

# %%
模型2 = GRU_集束(词汇总数 , 隐藏层尺寸,层数)
# Out:
# E:\Anaconda\envs\py36\lib\site-packages\ipykernel_launcher.py:81: UserWarning: The Param class is deprecated. Replace Param(default=N) by theano.In(value=N)

# %%
t1 = time.time()
for j in range(200):
    
    for i in range(70):

            输出=模型2.训练(包_输入[i],输入_遮罩_集[i],包_输出[i],输出_遮罩_集[i],包_输入[i].shape[1],学习率,0.9)
            if (i%10==0 and j%10==0):
                t2 = time.time()
                print("轮",j,"编号",i,输出[-1],'训练时间',(t2 - t1))

print ("单步训练时间: ~%f 秒" % ((t2 - t1) * 1.))
输出
# Out:
# E:\Anaconda\envs\py36\lib\site-packages\theano\tensor\subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# 轮 0 编号 0 13144.098 训练时间 0.7055971622467041
# 轮 0 编号 10 11838.783 训练时间 8.117412328720093
# 轮 0 编号 20 12077.9375 训练时间 15.166855096817017
# 轮 0 编号 30 12181.998 训练时间 22.17899250984192
# 轮 0 编号 40 13072.996 训练时间 29.526125192642212
# 轮 0 编号 50 9527.252 训练时间 36.81300401687622
# 轮 0 编号 60 12165.01 训练时间 43.783461570739746
# 轮 10 编号 0 11328.76 训练时间 505.0467486381531
# 轮 10 编号 10 10460.002 训练时间 512.278555393219
# 轮 10 编号 20 10546.098 训练时间 519.478182554245
# 轮 10 编号 30 10751.404 训练时间 526.6720108985901
# 轮 10 编号 40 11966.244 训练时间 533.9835987091064
# 轮 10 编号 50 8081.5073 训练时间 541.1823704242706
# 轮 10 编号 60 10859.41 训练时间 548.3924095630646
# 轮 20 编号 0 10355.304 训练时间 1009.0517213344574
# 轮 20 编号 10 9235.482 训练时间 1016.0628020763397
# 轮 20 编号 20 9551.25 训练时间 1023.0388171672821
# 轮 20 编号 30 9538.997 训练时间 1030.1131699085236
# 轮 20 编号 40 10559.67 训练时间 1037.316630601883
# 轮 20 编号 50 6788.911 训练时间 1044.7008199691772
# 轮 20 编号 60 9644.483 训练时间 1052.0008516311646
# 轮 30 编号 0 9170.809 训练时间 1500.873844385147
# 轮 30 编号 10 8383.715 训练时间 1507.906108379364
# 轮 30 编号 20 8739.338 训练时间 1514.8997066020966
# 轮 30 编号 30 8695.646 训练时间 1521.9100222587585
# 轮 30 编号 40 9273.664 训练时间 1529.072578907013
# 轮 30 编号 50 5849.7 训练时间 1536.100528717041
# 轮 30 编号 60 8460.511 训练时间 1543.09614610672
# 轮 40 编号 0 7918.522 训练时间 1991.6107795238495
# 轮 40 编号 10 6837.865 训练时间 1998.6717619895935
# 轮 40 编号 20 6904.891 训练时间 2005.842589378357
# 轮 40 编号 30 7146.5913 训练时间 2012.9714698791504
# 轮 40 编号 40 8726.115 训练时间 2020.0857348442078
# 轮 40 编号 50 4837.6177 训练时间 2027.1080679893494
# 轮 40 编号 60 7202.246 训练时间 2034.094928741455
# 轮 50 编号 0 6197.4307 训练时间 2486.871937274933
# 轮 50 编号 10 5678.6875 训练时间 2493.9013719558716
# 轮 50 编号 20 5576.751 训练时间 2500.9161410331726
# 轮 50 编号 30 5749.36 训练时间 2508.65624666214
# 轮 50 编号 40 6782.2285 训练时间 2516.0513365268707
# 轮 190 编号 60 199.36131 训练时间 9751.073762178421
# 单步训练时间: ~9751.073762 秒
# [array(248.16705, dtype=float32)]

# %%
import sys
sys.setrecursionlimit(15000)



with open('data/模型2_6_26', "wb") as mf:
     pickle.dump(模型2, mf)

# %%
with open('data/模型2_6_26', "rb") as mf:
       模型3= pickle.load(mf)

# %%
import sys
def print_sentence(s, index_to_word):
    sentence_str = [index_to_word[x] for x in s[1:-1]]
    print(" ".join(sentence_str))
    sys.stdout.flush()

def generate_sentence(model, index_to_word, word_to_index, min_length=5):
    # We start the sentence with the start token
    new_sentence = [word_to_index[SENTENCE_START_TOKEN]]
    print(new_sentence)
    # Repeat until we get an end token
    while not len(new_sentence)  < 20:
        next_word_probs = model.预测(new_sentence,1)[-1]
        samples = np.random.multinomial(1, next_word_probs[-1])
        sampled_word = np.argmax(samples)
        print(len(new_sentence))
        new_sentence.append(sampled_word)
        # Seomtimes we get stuck if the sentence becomes too long, e.g. "........" :(
        # And: We don't want sentences with UNKNOWN_TOKEN's
        if len(new_sentence) > 100 or sampled_word == word_to_index[UNKNOWN_TOKEN]:
            return None
    if len(new_sentence) < min_length:
        return None
    return new_sentence

def generate_sentences2(model, n, index_to_word, word_to_index):
    for i in range(n):
        sent = None
        while not sent:
            sent = generate_sentence(model, index_to_word, word_to_index)
        print_sentence(sent, index_to_word)

# %%
print(包_输入[0][:,1])
# oph=输入_遮罩_集[0][0,:]
# 测试1=1-oph[None,:]
# 测试2=np.ones((2,200))
# 测试3=测试1*测试2
# 测试3
# Out:
# [17872 17859 17827 12421 12971 17714 17814  3230 16627  3282   817 17501
#  15443 17813 17870]

# %%
for j in range(67,68):
#     p2=p.ones_like(输入_遮罩_集[j])
    结果_1=模型3.预测(包_输入[j],输入_遮罩_集[j],输入_遮罩_集[j],包_输入[j].shape[1])

    
    for k in range(结果_1[-1].shape[1]):
        new_sentence = [单词_到_下标[SENTENCE_START_TOKEN]]
        for i in range(len(结果_1[-1][:,k,:])):
        #samples = np.random.multinomial(1, 结果[-1][i])
            

            sampled_word = np.argmax(结果_1[-1][i,k,:])

            new_sentence.append(sampled_word)

        if j>=0:

            #print("次数",j )
            print("输入" )
            print_sentence(包_输入[j][:,k], 下标_到_单词)
            print("目标输出" )
            print_sentence(包_输出[j][:,k], 下标_到_单词)
            #print_sentence(X_train[j], 下标_到_单词)
            #print(包_输入[j][:,k])
            print("实际输出" )
            print_sentence(new_sentence, 下标_到_单词)
# Out:
# 输入
# 明年 买 格子 完美 格子 是 曼联 球迷 他哥 也 是 ？ <MASK/> <MASK/>
# 目标输出
# 是 曼联 球迷 他哥 也 是 ？ 各种 花式 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 格子 是 曼联 球迷 他哥 也 是 ？ 各种 花式 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 到底 信 哪个 ， 哎 这个 太扯 了 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 太扯 了 发图 的 照顾 下 小学 狗 ， 翻译 下 谢谢 SENTENCE_END
# 实际输出
# 这个 太扯 了 发图 的 照顾 下 小学 狗 ， 翻译 下 谢谢 SENTENCE_END <MASK/>
# 输入
# 同问 7 月 23 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
#
SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 吐 了 个 好 槽 鲁尼 跟 一帮 孩子 玩得 真 开心 <MASK/> <MASK/>
# 目标输出
# 跟 一帮 孩子 玩得 真 开心 罗霍 你 奶奶 的 放开 那 男孩
# 实际输出
# 鲁尼 跟 一帮 孩子 玩得 真 开心 罗霍 你 奶奶 的 放开 那 男孩 SENTENCE_END
# 输入
# 罗霍 你 奶奶 的 放开 那 男孩 青训 那 几个 关系 很 好 耶
# 目标输出
# 那 几个 关系 很 好 耶 和 波霸 关系 也 很 好 SENTENCE_END
# 实际输出
# 青训 那 几个 关系 很 好 耶 好 好 关系 也 很 好 SENTENCE_END <MASK/>
# 输入
# 我 抬 就是 有钱 用钱 砸死 丫 的 。 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 砸死 丫 的 。 没有 钱 不能 解决 的 事 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 用钱 砸死 丫 的 。 没有 钱 不能 解决 的 事 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 屌 这个 太吊 了 。 。 。 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 太吊 了 。 。 。 求 扔 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 这个 太吊 了 。 。 。 求 扔 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 笑 死 了 笑 尿 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 尿 漫画 宣 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 笑 尿 漫画 宣 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 三德爷 威武 稳如 金币 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 金币 少 了 个 马 洛塔 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 稳如 金币 少 了 个 马 洛塔 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 少 了 个 马 洛塔 稳如 漫画 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 漫画 这个 图 在 哪里 可以 看到 ， 或者 关注 什么 ？ SENTENCE_END
# 实际输出
# 稳如 漫画 这个 图 在 哪里 可以 看到 ， 或者 关注 什么 ？ SENTENCE_END <MASK/>
# 输入
# 琼斯 换个 号码 妥妥 的 在 哪里 训练 啊 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 哪里 训练 啊 已经 买 了 曼市 德比 的 票 了 SENTENCE_END <MASK/>
# 实际输出
# 在 哪里 训练 啊 已经 买 了 曼市 德比 的 票 了 SENTENCE_END <MASK/> <MASK/>
# 输入
# 这个 没 可能 马诺 拉斯 不是 不 续约 了 吗 抬 一手 <MASK/> <MASK/>
# 目标输出
# 拉斯 不是 不 续约 了 吗 抬 一手 卧槽 要 买 多少 人
# 实际输出
# 马诺 拉斯 不是 不 续约 了 吗 抬 一手 卧槽 的 买 多少 人 SENTENCE_END
# 输入
# 买买 买买 买 哈哈哈 哈哈哈 这个 没 可能 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 没 可能 这个 能来 我 给 穆鸟 跪下 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 这个 没 还是 这个 能来 我 给 给 跪下 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 4 / 3 估计 法比 尼奥 不会 来 了 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 法比 尼奥 不会 来 了 法比 尼奥 得 砸 啊 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 估计 法比 尼奥 不会 来 了 法比 尼奥 得 砸 啊 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 真 多 妹子 一直 觉得 多特 的 球衣 是 真 好看 <MASK/> <MASK/> <MASK/>
# 目标输出
# 觉得 多特 的 球衣 是 真 好看 香草 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 一直 觉得 多特 的 球衣 是 真 好看 香草 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 没 体操 排球 看 了 应该 只是 田径 没有 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 只是 田径 没有 俄罗斯 估计 会 退出 了 吧 ？ SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 应该 只是 田径 没有 俄罗斯 估计 会 退出 了 吧 ？ SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 这 配置 天空 城 够用 了 欧洲杯 这 表现 也 卖 ？ <MASK/> <MASK/>
# 目标输出
# 这 表现 也 卖 ？ 抬 过 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 欧洲杯 这 表现 也 卖 ？ 抬 过 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
#
<MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 有 可能 有 号码 的 是不是 代表 不会 被 卖 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 很 有 可能 有 号码 的 是不是 代表 有 被 卖 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 难得 还有 记得 我大 囧 尼 的 7 年 啦 你 这个 id <MASK/>
# 目标输出
# 年 啦 你 这个 id 上 一个 6 号 是 谁 ？ SENTENCE_END
# 实际输出
# 7 年 啦 你 这个 id 上 一个 6 号 是 谁 ？ SENTENCE_END <MASK/>
# 输入
# 上 一个 6 号 是 谁 ？ 埃文斯 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 队草 ， 囧 尼 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 埃文斯 队草 ， 囧 尼 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 队草 ， 囧 尼 那 2 号 呢 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 2 号 呢 拉斐尔 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 那 2 号 呢 拉斐尔 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 这图 有毒 ， 现在 终于 知道 这图 啥意思 了 六号 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 66666 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 六号 66666 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 手势 宣 是 1 .2 e <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 1 .2 e 666666 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 是 1 .2 e 666666 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 666666 明明 是 一身 白 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 是 一身 白 服 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 明明 是 一身 白 服 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 服 服 ！ <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# ！ 就 剩下 6 号 哈哈哈 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 服 ！ 就 剩下 6 号 哈哈哈 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 就 剩下 6 号 哈哈哈 有毒 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 老子 1 .2 亿 身价 ， 穿 6 号 。 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 有毒 老子 1 .2 亿 身价 ， 穿 6 号 。 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 凯尔特人 那个 是 罗杰斯 -- - 贴 吧 极速 版 for uwp 哦 哦
# 目标输出
# 哦 谢谢 老 特拉福德 滑轨 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 哦 哦 谢谢 老 特拉福德 滑轨 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 这么 多 比赛 轮换 也 不错 今年 应该 就是 如此 了 ~ <MASK/> <MASK/>
# 目标输出
# 应该 就是 如此 了 ~ w SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 今年 应该 就是 如此 了 ~ w SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 死 胖子 快 了 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 了 。 。 。 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 快 了 。 。 。 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 的确 啊 钱 的 问题 就 不是 问题 了 . . . . <MASK/>
# 目标输出
# 的 问题 就 不是 问题 了 . . . . 麻痹 死 胖子
# 实际输出
# 钱 的 问题 就 不是 问题 了 . . . . . 死 胖子 SENTENCE_END
# 输入
# 这是 什么 套路 ？ 马 退敌 和 马蒂奇 ？ <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 退敌 和 马蒂奇 ？ 感觉 是 在 压价 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 马 退敌 和 马蒂奇 ？ 感觉 是 在 压价 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 不会 因为 佣金 闹 黄 了 吧 哪边 搞定 了 ？ <MASK/> <MASK/> <MASK/>
# 目标输出
# 搞定 了 ？ 感觉 悬 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 哪边 搞定 了 ？ 感觉 悬 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 皇马 被 截胡 了 又 怪 传真机 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 怪 传真机 啊 哈哈哈哈 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 又 怪 传真机 啊 哈哈哈哈 SENTENCE_END SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 娜娜 继续 买 法国 球员 娜娜 要 ， 5000w 最少 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 要 ， 5000w 最少 他 去年 就 说 想 离队 吧 SENTENCE_END <MASK/>
# 实际输出
# 娜娜 要 ， 5000w 最少 他 去年 就 说 想 离队 吧 SENTENCE_END <MASK/> <MASK/>
# 输入
# 他 去年 就 说 想 离队 吧 去 大 巴黎 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 大 巴黎 4000 万欧 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 去 大 巴黎 4000 万欧 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 周日 能官 宣 吗 我 觉得 悬 ～ <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 觉得 悬 ～ 穆里尼奥 就是 霸气 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 我 觉得 悬 ～ 穆里尼奥 就是 霸气 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 卧槽 卧槽 抬抬 抬 ， 抬 手里 最好 他 真的 不错 啊 <MASK/> <MASK/>
# 目标输出
# 真的 不错 啊 抬 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 他 真的 不错 啊 抬 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 这个 可以 买 这个 真不错 的 。 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 真不错 的 。 梅吹 也 不 愿意 坐板凳 吧 ？ SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 这个 真不错 的 。 梅吹 也 不 愿意 坐板凳 吧 ？ SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 求 翻译 求 翻译 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 翻译 求 翻译 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 求 翻译 求 翻译 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 求 翻译 啥意思 ？ 文盲 求 翻译 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# ？ 文盲 求 翻译 这 什么 语 。 。 。 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 啥意思 ？ 文盲 求 翻译 这 什么 语 。 。 。 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 这 很 888 不 愿意 支付 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 愿意 支付 果然 不要脸 ， 以后 叫 尤 婊 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 不 愿意 支付 果然 不要脸 ， 以后 叫 尤 婊 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 曾志伟 影帝 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 笑 出来 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 影帝 笑 出来 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 希望 是 吧 哈哈哈 好消息 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 稳 了 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 好消息 稳 了 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 要 被 虐 了 嗯 ， 懂法 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# ， 懂法 不好 搞 啊 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 嗯 ， 懂法 不好 搞 啊 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 不好 搞 啊 全 主力 啊 ， 可以 的 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 主力 啊 ， 可以 的 哎 ， 香川 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 全 主力 啊 ， 可以 的 哎 ， 香川 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 门萨 呢 穆鸟 在 实验 整个 中轴线 的 组合 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 在 实验 整个 中轴线 的 组合 布林德 终于 回归 中场 了 SENTENCE_END <MASK/>
# 实际输出
# 穆鸟 在 实验 整个 中轴线 的 组合 布林德 终于 回归 中场 了 SENTENCE_END <MASK/> <MASK/>
# 输入
# 这才 是 教授 的 节奏 博尔顿 啊 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 啊 记错 了 。 。 — — 来自 爱贴 吧 windows phone 客户端
# 实际输出
# 博尔顿 啊 记错 了 。 。 — — 来自 爱贴 吧 windows phone 客户端 SENTENCE_END
# 输入
# 真假 ？ mutv 宣 ？ <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 宣 ？ 假 的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# mutv 宣 ？ 假 的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 假 的 666 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 真的假 的 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 666 真的假 的 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 真的假 的 ？ … … <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# … 真的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# … … 真的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 他 有 黑人 血统 吗 感觉 起码 有 埃及 血统 。 。 。 <MASK/>
# 目标输出
# 起码 有 埃及 血统 。 。 。 曼联 历史 最佳 后卫 SENTENCE_END <MASK/>
# 实际输出
# 感觉 起码 有 埃及 血统 。 。 。 曼联 历史 最佳 后卫 SENTENCE_END <MASK/> <MASK/>
# 输入
# 楼上 一群 傻缺 懂球帝 顶 你 ， 这句 话 我 支持 <MASK/> <MASK/> <MASK/>
# 目标输出
# 你 ， 这句 话 我 支持 懂球帝 就 会 敲 键盘 SENTENCE_END <MASK/>
# 实际输出
# 顶 你 被 这句 话 我 支持 懂球帝 就 会 敲 键盘 SENTENCE_END <MASK/> <MASK/>
# 输入
# 都 怪 你 这 艾迪 这是 米兰 体育报 的 消息 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 米兰 体育报 的 消息 38 又 买 后卫 阿 … SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 这是 米兰 体育报 的 消息 38 又 买 后卫 阿 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 表妹 怎么 花 出去 两亿 的 ？ 38 咋 都 排 第三 了 <MASK/>
# 目标输出
# 咋 都 排 第三 了 阿森纳 呢 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 38 咋 都 排 第三 了 阿森纳 呢 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 林家 德 昨晚 那脚 射门 让 人 蛋 疼 林 加德 躺 枪 <MASK/>
# 目标输出
# 加德 躺 枪 昨晚 那脚 射门 难道 不是 回传 门将 吗 ？ SENTENCE_END
# 实际输出
# 林 加德 躺 枪 昨晚 那脚 射门 难道 不是 回传 门将 吗 ？ SENTENCE_END <MASK/>
# 输入
# 可以 对方 主帅 认了 ， 没跑 了 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 主帅 认了 ， 没跑 了 快 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 对方 主帅 认了 ， 没跑 了 快 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 看 第一句 老 以为 你 是 卧底 往下 看 呢 ？ <MASK/> <MASK/> <MASK/>
# 目标输出
# 看 呢 ？ 真 红魔 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 往下 看 呢 ？ 真 红魔 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 一千 的 是 球员 版 不然 每年 的 赞助费 靠 啥 挣 回来 <MASK/>
# 目标输出
# 每年 的 赞助费 靠 啥 挣 回来 明年 7 月份 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 不然 每年 的 赞助费 靠 啥 挣 回来 明年 7 月份 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 一语中的 ! ! ! 卢卡 库 不是 车 走 的 吗 <MASK/> <MASK/> <MASK/>
# 目标输出
# 没有 黑人 球员 肖 总是 这个 傲娇 的 表情 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 怎么 没有 黑人 球员 肖 总是 这个 傲娇 的 表情 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 欧洲 体育 ： 马 赫雷斯 决定 加盟 阿森纳 卧槽 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 上树 了 ， 上树 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 卧槽 上树 了 ， 上树 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 上树 了 ， 上树 了 不 可能 ！ <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 可能 ！ 骗 谁 呢 ， 4500 万磅 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 不 可能 ！ 骗 谁 呢 ， 4500 万磅 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 稳 莫 爵爷 加油 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 爵爷 加油 虎 扑 已 开始 队形 表演 ！ SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 莫 爵爷 加油 虎 扑 已 开始 队形 表演 ！ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 非常 有 可能 还有 罗霍 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 罗霍 不是 去 西甲 了 么 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 还有 罗霍 不是 去 西甲 了 么 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 不是 去 西甲 了 么 很大 几率 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 几率 可以 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 很大 几率 可以 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 楼主 说 的 好 + 1 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 1 娜 也 可以 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# + 1 娜 也 可以 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 角度 刁钻 而且 要 努力 当 上 队长 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 要 努力 当 上 队长 有理有据 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 而且 要 努力 当 上 队长 有理有据 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 重点 ！ 李菊福 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 有 道理 啊 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 李菊福 有 道理 啊 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 实在 看不懂 当初 为什么 选择 他 当 主教练 。 备胎 的 备胎 <MASK/> <MASK/>
# 目标输出
# 的 备胎 老头子 推荐 的 苏格兰 老乡 . . . SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 备胎 的 备胎 老头子 推荐 的 苏格兰 老乡 . . . <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 浙江 也 是 ， 热死 了 还是 东北 凉快 啊 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 东北 凉快 啊 都 是 济南 的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 还是 东北 凉快 啊 都 是 济南 的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 伊瓜 因 和 尤文 签约 至 2020 年 。 多少 钱 ？ <MASK/> <MASK/>
# 目标输出
# 钱 ？ 888 哪来 那么 多钱 呢 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 多少 钱 ？ 888 哪来 那么 多钱 呢 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 卧槽 看来 是 付 了 9400 万欧 啊 。 哈哈哈 。 <MASK/> <MASK/> <MASK/>
# 目标输出
# 是 付 了 9400 万欧 啊 。 哈哈哈 。 哪来 的 钱 ？
# 实际输出
# 看来 是 付 了 9400 万欧 啊 。 哈哈哈 。 哪来 的 钱 ？ SENTENCE_END
# 输入
# 解约 条款 不 可以 分期 付 。 稳如 激活 伊瓜 因 解约 条款 <MASK/>
# 目标输出
# 激活 伊瓜 因 解约 条款 这人 靠 谱 吗 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 稳如 激活 伊瓜 因 解约 条款 这人 靠 谱 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 可靠 啊 皇马 拒绝 支付 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 拒绝 支付 ok 👌 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 皇马 拒绝 支付 ok 👌 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 这 很 888 风格 依旧 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 依旧 波霸 赶紧 的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 风格 依旧 波霸 赶紧 的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 看不到 官宣 还是 担心 这个 可以 谈 的 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 可以 谈 的 不官 宣 不下 树 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 这个 可以 谈 的 不官 宣 不下 树 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 这特 么 得 再 树上 蹲 一 夏天 又 下树 了 <MASK/> <MASK/> <MASK/>
# 目标输出
# 下树 了 我 想 知道 娜娜 这个 夏天 买 了 谁 SENTENCE_END <MASK/>
# 实际输出
# 又 下树 了 我 想 知道 娜娜 这个 夏天 买 了 谁 SENTENCE_END <MASK/> <MASK/>
# 输入
# 哦 又 分期 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 分期 也就是说 我 魔 还 没 给 888 付款 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 又 分期 也就是说 我 魔 还 没 给 888 付款 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 原来 违约金 也 能 分期 。 。 要 黄 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 黄 888 买人 就 分期 ， 卖人 可 不会 分期 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 要 黄 888 买人 888 分期 ， 卖人 可 不会 分期 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 自己 看 原文 吧 ， 就是 这个 意思 解释 的 不错 <MASK/> <MASK/> <MASK/>
# 目标输出
# 的 不错 好 吧 ， 英文 不 好看 得 快 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 解释 的 不错 好 吧 ， 英文 不 得 得 快 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 不错 ， 卡神 很 精神 黑暗 中 的 天使 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 中 的 天使 自拍 的 巅峰 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 黑暗 中 的 天使 自拍 的 巅峰 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 哇 ， 卡里克 好帅 妈 的 ， 卡神 在 哪里 ？ <MASK/> <MASK/> <MASK/>
# 目标输出
# 的 ， 卡神 在 哪里 ？ 黝黑 我卡 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 妈 的 ， 卡神 在 哪里 ？ 黝黑 我卡 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 擦 888 又 少 了 一个 替补 人选 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 又 少 了 一个 替补 人选 。 。 。 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 888 又 少 了 一个 替补 人选 。 。 。 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 有 一个 蓬蓬 头 这 不是 888 的 目标 ？ <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 不是 888 的 目标 ？ 888 给 不起 转会费 和 工资 SENTENCE_END <MASK/>
# 实际输出
# 这 不是 888 的 目标 ？ 888 给 不起 转会费 和 工资 SENTENCE_END <MASK/> <MASK/>
# 输入
# 很快 搞定 也 说 了 一个 星期 了 继续 买 流量 <MASK/> <MASK/> <MASK/>
# 目标输出
# 买 流量 正常 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 继续 买 流量 正常 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 不要 买 了 真的 算了 别买 了 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 别买 了 撤 吧 在 加价 我 魔 可能 就 不会 出 了
# 实际输出
# 算了 别买 了 撤 吧 在 加价 我 魔 可能 不会 不会 出 了 SENTENCE_END
# 输入
# 卧槽 现在 是 个人 都 值 三千万 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 是 个人 都 值 三千万 可以 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 现在 是 个人 都 值 三千万 可以 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 酱紫 有 啥 天赋 也 没有 上来 就 报 三千万 的 。 。 。
# 目标输出
# 啥 天赋 也 没有 上来 就 报 三千万 的 。 。 。 …
# 实际输出
# 有 啥 天赋 也 没有 上来 就 报 三千万 的 。 。 。 … SENTENCE_END
# 输入
# 看 住 集锦 不错 ， 感觉 比 那个 7 号 强 就是 耶稣 <MASK/>
# 目标输出
# 耶稣 好 ， 哈哈哈 哈哈哈 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 就是 耶稣 好 ， 哈哈哈 哈哈哈 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 去 吧 真的 吗 ， 那要 去 训练场 等 吗 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 吗 ， 那要 去 训练场 等 吗 其实 我 觉得 有戏 SENTENCE_END <MASK/>
# 实际输出
# 真的 吗 ， 那要 去 训练场 等 吗 其实 我 觉得 有戏 SENTENCE_END <MASK/> <MASK/>
# 输入
# 娜娜 的 存钱罐 亮 了 教授 站位 第四 ， 作者 高端 黑 <MASK/> <MASK/>
# 目标输出
# 站位 第四 ， 作者 高端 黑 下 一个 可能 是 罗 指导 吗
# 实际输出
# 教授 站位 第四 ， 作者 高端 黑 下 一个 可能 是 罗 指导 吗 SENTENCE_END
# 输入
# 下 一个 可能 是 罗 指导 吗 外国人 也 知道 娜 四 ？ <MASK/>
# 目标输出
# 也 知道 娜 四 ？ 哈哈 ， 高端 黑 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 外国人 也 知道 娜 四 ？ 哈哈 ， 高端 黑 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 哈哈 ， 高端 黑 穆鸟 站 第一 ？ 作者 是 红魔 <MASK/> <MASK/> <MASK/>
# 目标输出
# 站 第一 ？ 作者 是 红魔 那 铜像 是 谁 ？ SENTENCE_END <MASK/>
# 实际输出
# 穆鸟 站 第一 ？ 作者 是 红魔 是 铜像 是 谁 ？ SENTENCE_END <MASK/> <MASK/>
# 输入
# 莫耶斯 那 拿 着 枪 的 呢 ？ <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 拿 着 枪 的 呢 ？ 也 是 莫耶斯 ？ SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 那 拿 着 枪 的 呢 ？ 也 是 莫耶斯 ？ SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 也 是 莫耶斯 ？ 教授 那个 存钱罐 好 可爱 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 那个 存钱罐 好 可爱 莫 爵爷 回来 了 。 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 教授 那个 存钱罐 好 可爱 莫 爵爷 回来 了 。 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 莫 爵爷 回来 了 。 就 问 你们 怕不怕 ~ <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 问 你们 怕不怕 ~ 全世界 的 梗 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 就 问 你们 怕不怕 ~ 全世界 的 梗 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 该 换 目标 了 去 他妈的 888 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 他妈的 888 是 时候 撤 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 去 他妈的 888 都 时候 撤 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 梅西 刚刚 换 了 个 琼斯 的 发型 煤球 💊 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 💊 这 不是 拉姆 塞 吗 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 煤球 💊 这 不是 拉姆 塞 吗 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 中国 足球 是 我 说 的 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 我 说 的 所以 前 几天 有人 因为 场地 太 差 断腿 了
# 实际输出
# 是 我 说 的 所以 前 几天 有人 因为 场地 太 差 断腿 了 SENTENCE_END
# 输入
# 可怜 老穆 又 要 被 喷 了 踢 人 啊 ， 谁 还 踢球
# 目标输出
# 人 啊 ， 谁 还 踢球 功夫 足球 。 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 踢 人 啊 ， 谁 还 踢球 功夫 足球 。 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 嗯 嗯 ， 必须 的 这 交易 确实 挺 复杂 的 。 。 。
# 目标输出
# 交易 确实 挺 复杂 的 。 。 。 壮士 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 这 交易 确实 挺 复杂 的 。 。 。 壮士 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 壮士 低调 。 。 。 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
#
<MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 是 去 哪 从 酒店 出来 了 ， 还 不 知道 SENTENCE_END <MASK/>
# 实际输出
# 这 是 去 哪 从 酒店 出来 了 ， 还 不 知道 SENTENCE_END <MASK/> <MASK/>
# 输入
# 从 酒店 出来 了 ， 还 不 知道 准备 飞 回 曼彻斯特 了 <MASK/>
# 目标输出
# 飞 回 曼彻斯特 了 去 哪里 吗 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 准备 飞 回 曼彻斯特 了 去 哪里 ？ ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 南美 球员 真的 适合 我 抬 么 这人 踢 什么 位置 的 <MASK/> <MASK/>
# 目标输出
# 踢 什么 位置 的 是 那个 巴西 耶稣 吗 ？ SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 这人 踢 什么 位置 的 是 那个 巴西 耶稣 吗 ？ SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 是 那个 巴西 耶稣 吗 ？ 对 的 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 的 耶稣 哥 ？ 那个 大 妖人 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 对 的 耶稣 哥 ？ 那个 大 妖人 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 耶稣 哥 ？ 那个 大 妖人 假 的 一匹 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 的 一匹 一言不合 违约金 啊 ， 真 土豪 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 假 的 一匹 一言不合 违约金 啊 ， 真 土豪 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 哈哈哈 哈哈哈 ， 好 2000 万 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 万 特维斯 那年 表现 还是 不错 的 吧 ， 可惜 没 留下 SENTENCE_END
# 实际输出
# 2000 万 特维斯 那年 表现 还是 不错 的 吧 ， 吧 没 留下 SENTENCE_END <MASK/>
# 输入
# 我 艹 很 强 很 不错 可以 的 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 的 加油 三德子 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 可以 的 加油 三德子 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 加油 三德子 又 要 再 在 树上 呆 一天 … <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 要 再 在 树上 呆 一天 … 矿工 的 电量 永远 着急 SENTENCE_END
# 实际输出
# 又 要 再 在 树上 呆 一天 … 矿工 的 电量 永远 着急 SENTENCE_END <MASK/>
# 输入
# 上 树 。 就是 这个 ， 憋屈 啊 这 两天 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 这个 ， 憋屈 啊 这 两天 啊啊啊 啊 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 就是 这个 ， 憋屈 啊 这 两天 啊啊啊 啊 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 被盗 了 两次 号 你 快 回来 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 快 回来 嗯 ， 改 了 个 复杂 点 的 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 你 快 回来 嗯 ， 改 了 个 复杂 点 的 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 嗯 ， 改 了 个 复杂 点 的 修车 修 的 号 被盗 了
# 目标输出
# 修 的 号 被盗 了 被 扫黄 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 修车 修 的 号 被盗 了 被 扫黄 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 鸡鸡 ！ 矿工 电量 期待 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 矿工 这 电量 每次 都 是 槽 点 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 期待 矿工 这 电量 每次 都 是 槽 点 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 这个 应该 是 拉 胖子 了 是 的 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 的 这 是 拉 胖子 ， 那天 那个 不是 。 这个 是 。
# 实际输出
# 是 的 这 是 拉 这个 ， 那天 这个 不是 。 这个 是 。 SENTENCE_END
# 输入
# 真 tm 成 肥皂剧 了 卸载 贴 吧 到 社区 盾 <MASK/> <MASK/> <MASK/>
# 目标输出
# 贴 吧 到 社区 盾 最后 留队 的 节奏 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 卸载 贴 吧 到 社区 盾 最后 留队 的 节奏 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 坐等 中超 截胡 就服 你 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 你 砸 ！ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 就服 你 砸 ！ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 没 办法 ， 888 俱乐部 最 擅长 打电话 了 啊 老哥 稳 <MASK/> <MASK/>
# 目标输出
# 稳 不用 电话 不 习惯 啊 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 老哥 稳 不用 电话 不 习惯 啊 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 鸭子 和 马塔 又 坐在 一起 瞎说 ， 旁边 都 是 空气 <MASK/> <MASK/>
# 目标输出
# ， 旁边 都 是 空气 肖 的 眼睛 发 直 。 。 SENTENCE_END
# 实际输出
# 瞎说 ， 旁边 都 是 空气 肖 的 眼睛 发 直 。 。 SENTENCE_END <MASK/>
# 输入
# 队员 们 回到 曼彻斯特 。 好 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 转会 消息 没 了 ， 正在 谈判 吗 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 好 转会 消息 没 了 ， 正在 谈判 吗 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 伊布 离开 酒店 ， 去 训练场 了 。 明天 凌晨 真的 有 热身赛 吗
# 目标输出
# 凌晨 真的 有 热身赛 吗 有 啊 ， 但 预计 不是 一队 SENTENCE_END
# 实际输出
# 明天 凌晨 真的 有 热身赛 吗 有 啊 ， 但 预计 不是 一队 SENTENCE_END <MASK/>
# 输入
# 底下 回复 没看 懂 想 表达 什么 曼城 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 其实 是 马德里 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 曼城 其实 是 马德里 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 666 好 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 稳 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 好 稳 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 抬 完 就 走 ， 好 刺激 啊 去年 一口气 买 了 10 几个
# 目标输出
# 一口气 买 了 10 几个 官宣 了 好像 意大利 天空 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 去年 一口气 买 了 10 几个 官宣 好像 好像 意大利 天空 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 然而 欧联杯 … 挺 帅气 的 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 帅气 的 瓦 百万 还是 不 给 机会 啊 ， 娘 的 。
# 实际输出
# 挺 帅气 的 瓦 百万 还是 不 给 机会 啊 ， 娘 的 。 SENTENCE_END
# 输入
# 取消 取消 ， 不 来 算了 。 熟悉 的 节奏 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 的 节奏 抬 完 就 走 这次 玩 的 有点 大 SENTENCE_END <MASK/>
# 实际输出
# 熟悉 的 节奏 抬 完 就 走 这次 玩 的 有点 SENTENCE_END SENTENCE_END <MASK/> <MASK/>
# 输入
# 这 也 行 稳 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 9 - 3 - 2 - 0 已 最 已 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 稳 9 - 3 - 2 - 0 已 最 已 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 为啥 不上 个 伊布 玩玩 0 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 1 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 0 1 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 1 1 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 完全 没有 消息 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 1 完全 没有 消息 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 完全 没有 消息 兹拉坦 不 踢 预备队 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 不 踢 预备队 最终 比分 多少 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 兹拉坦 不 踢 预备队 最终 比分 多少 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 卧槽 尼玛 个 光头 请 拿出 1e 大洋 来 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 拿出 1e 大洋 来 好 ， 快 买 有钱 你 就 买 SENTENCE_END
# 实际输出
# 请 拿出 1e 大洋 来 好 ， 快 买 有钱 你 就 买 SENTENCE_END <MASK/>
# 输入
# 好 ， 快 买 有钱 你 就 买 钱 呢 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 呢 没钱 还 bb 真 不要脸 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 钱 呢 没钱 还 bb 真 不要脸 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 没钱 还 bb 真 不要脸 马戏团 就 特 么 爱 蹭 头条 <MASK/> <MASK/>
# 目标输出
# 就 特 么 爱 蹭 头条 新浪 的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 马戏团 就 特 么 爱 蹭 头条 新浪 的 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 抬价 吧 皇马 不是 说 还 准备 买 维拉 蒂 吗 <MASK/> <MASK/> <MASK/>
# 目标输出
# 不是 说 还 准备 买 维拉 蒂 吗 就是 最新 发布会 说 的
# 实际输出
# 皇马 不是 说 还 准备 一个 那 的 吗 就是 最新 发布会 说 的 SENTENCE_END
# 输入
# 中 前卫 潜力 咋样 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 咋样 上限 杰拉德 ， SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 潜力 咋样 上限 杰拉德 ， SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 上限 杰拉德 ， 主要 是 颜值 高 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 是 颜值 高 又 吹 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 主要 是 颜值 高 又 吹 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 加油 ！ ！ ！ ！ 加油 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 加油 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 加油 加油 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 加油 ！ 有 一种 c 罗 的 感觉 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 一种 c 罗 的 感觉 加油 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 有 一种 c 罗 的 感觉 加油 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 加油 原来 他娘 也 是 球 二代 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 他娘 也 是 球 二代 加油 ！ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 原来 他娘 也 是 球 二代 加油 ！ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 林佳德 就 在 眼前 啊 林嘉德 好歹 在 足总杯 绝杀 <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 好歹 在 足总杯 绝杀 他娘 情商 不错 ， 加油 ！ SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 林嘉德 好歹 在 足总杯 绝杀 他娘 情商 不错 不错 不错 ！ SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 阔以 刚 ？ <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# ？ 翻译 下 什么 意思 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 刚 ？ 翻译 下 什么 意思 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 这 是 官 推 ？ 不 可能 吧 肯定 是 啊 。 认证 <MASK/>
# 目标输出
# 是 啊 。 认证 要是 官 推 呢 ？ SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 肯定 是 啊 。 认证 要是 官 推 呢 ？ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 对 本来 表妹 没 几个 球迷 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 表妹 没 几个 球迷 总 要 有人 宣传 球队 的 SENTENCE_END <MASK/> <MASK/>
# 实际输出
# 本来 表妹 没 几个 球迷 总 要 有人 宣传 球队 的 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入
# 辛苦 了 矿工 三德子 ： 支付宝 还是 微信 ？ <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# ： 支付宝 还是 微信 ？ 大神 ， 来源 靠 谱 吗 SENTENCE_END <MASK/>
# 实际输出
# 三德子 ： 支付宝 还是 微信 ？ 大神 ， 来源 靠 谱 吗 SENTENCE_END <MASK/> <MASK/>
# 输入
# 传真机 不能 坏 啊 ！ 8000 + 2000 浮动 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# + 2000 浮动 那就好 。 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 8000 + 2000 浮动 那就好 。 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 分 888 期 呗 否则 我 不 可能 发出 来 的 <MASK/> <MASK/> <MASK/>
# 目标输出
# 我 不 可能 发出 来 的 矿工 稳 ！ SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 否则 我 不 可能 来 来 的 矿工 稳 ！ SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 尤文 就是 屌 别急 一个 转会 就 超过 他们 <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 目标输出
# 一个 转会 就 超过 他们 我 抬 表示 呵呵 SENTENCE_END <MASK/> <MASK/> <MASK/>
# 实际输出
# 别急 一个 转会 就 超过 他们 我 抬 表示 呵呵 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 车子 买 了 坎特 还 买 谁 了 那个 比利时 前锋 <MASK/> <MASK/> <MASK/>
# 目标输出
# 比利时 前锋 哦 对 想 起来 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 实际输出
# 那个 比利时 前锋 哦 对 想 起来 了 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入
# 人家 卖 了 一条 中轴线 呢 拜仁 的 8000 万 呢 ？ <MASK/> <MASK/>
# 目标输出
# 的 8000 万 呢 ？ 马桶 又 开始 买 彩票 了 么 SENTENCE_END
# 实际输出
# 拜仁 的 8000 万 呢 ？ 马桶 又 开始 买 彩票 了 么 SENTENCE_END <MASK/>

# %% [markdown]
# 不知什么原因，训练到的数据能得出很好的结果，但是没有训练到的几乎就是乱的

# %%
print("输入 q 退出")
import jieba
def clearn_str(s):
	s = re.sub(r"\s+", " ", s)
	s = re.sub(r"\-", "", s)
	return 'SENTENCE_START '+s

def tokenize(s):
	"""
	very raw tokenizer
	"""
	#s = clearn_str(s)
	return s.strip().split(" ")
for ai in range(100):
    

    问话= input("输入: ")
    if 问话=='q':
        break
    问话3=''
    for word in (jieba.cut(问话)):
        问话3+= word+' '
    问话1=clearn_str(问话3)

    问话_表=tokenize(问话1)
    
    问话_下标=[单词_到_下标.setdefault(问话_分,1) for 问话_分 in  问话_表]
    if 1 in 问话_下标:
        print("_______________________________出现未知字符")
    长度=len(问话_下标)
    问话_下标=np.array(问话_下标)
   # print(问话_下标)
    问话_下标=问话_下标.reshape(长度,1)
    遮罩_入=np.ones_like(问话_下标)
    #print(问话_下标.shape)
   # print(遮罩_入.shape)
    for 计数1 in range(15-长度):
        问话_下标=np.append(问话_下标,0)
        遮罩_入=np.append(遮罩_入,0)
    问话_下标=问话_下标.reshape((15,1))
    遮罩_入=遮罩_入.reshape((15,1))
    遮罩_出=np.ones((15,1))
    结果_1=模型3.预测(问话_下标,遮罩_入,遮罩_出,问话_下标.shape[1])




    for k in range(结果_1[-1].shape[1]):
        new_sentence = [单词_到_下标[SENTENCE_START_TOKEN]]
        for i in range(len(结果_1[-1][:,k,:])):
            #samples = np.random.multinomial(1, 结果[-1][i])


            sampled_word = np.argmax(结果_1[-1][i,k,:])

            new_sentence.append(sampled_word)

        if j>=0:



            print_sentence(new_sentence, 下标_到_单词)
    #print_sentence(问话_下标, 下标_到_单词)
# Out:
# 输入 q 退出
# 输入: 你好
# 苏苏 你好 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入: 你好啊
# 加油 哭 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入: 你叫啥
# 虽然 你 你 是 这 我 前 起来 哈哈哈哈 … SENTENCE_END <MASK/> <MASK/> <MASK/>
# 输入: 中国足球
# 齐达内 94 克林斯曼 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入: 踢球
# 刚 说 吃 吃 ， <MASK/> 年 SENTENCE_END <MASK/> <MASK/> <MASK/> <MASK/> <MASK/> <MASK/>
# 输入: 大神 最近 回 我 蛮 多 的 哈哈哈 ， 这个 好
# 哈哈哈 ， 这个 好 大神 都 发话 了 ， 问 乳沟 SENTENCE_END <MASK/> <MASK/>
# 输入: 卧槽 ， 大神 果然 是 大神 我 居然 出现 在 截图 中
# 我 居然 出现 在 截图 中 让 吧 说 一下 波霸 SENTENCE_END 吧 SENTENCE_END
# 输入: 卧槽 大神 果然 是 大神 我 居然 出现 在 截图 中
# 我 对 出现 在 大神 中 让 大神 大神 一下 没 大神 <MASK/> SENTENCE_END
# 输入: 大神 果然 是 大神 我 居然 出现 在 截图 中
# 我 是 我 在 截图 中 让 大神 ， 一下 888 SENTENCE_END SENTENCE_END SENTENCE_END
# 输入: 卧槽 ，果然 是 大神 我 居然 出现 在 截图 中
# 我 ！ 出现 我 截图 了 让 让 说 一下 波霸 吧 吧 SENTENCE_END
# 输入: q
